# %%
import os
import glob
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from PIL import Image
import cv2

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import KFold

import albumentations as A
from albumentations.pytorch import ToTensorV2

from monai.losses import TverskyLoss
from monai.losses import DiceLoss

from torch.utils.data import WeightedRandomSampler


import torch
import torch.nn as nn
import torch.nn.functional as F
from scipy.ndimage import distance_transform_edt
from dynamic_network_architectures.architectures.unet import PlainConvUNet
from torch.amp import autocast, GradScaler


device = (
    "cuda" if torch.cuda.is_available() 
    else "mps" if torch.backends.mps.is_available() 
    else "cpu"
)
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
# Define paths
DATA_DIR = './T1/'
IMAGE_DIR = './images/'
MASK_DIR = './masks/'

# Create directories if they don't exist
os.makedirs(IMAGE_DIR, exist_ok=True)
os.makedirs(MASK_DIR, exist_ok=True)

# Get a list of patient folders
patient_folders = sorted(glob.glob(os.path.join(DATA_DIR, 'IOG*')))

# %%
import json

SLICE_MAP_PATH = 'slice_tumor_map.json'

def extract_and_save_slices(patient_folders, image_dir, mask_dir):
    """Extract slices and create a map tracking which have tumor segmentation."""
    slice_tumor_map = {}  # filename -> has_tumor (bool)
    
    for patient_folder in patient_folders:
        patient_id = os.path.basename(patient_folder)
        try:
            img_path = glob.glob(os.path.join(patient_folder, '*[!_roi].nii.gz'))[0]
            mask_path = glob.glob(os.path.join(patient_folder, '*_roi.nii.gz'))[0]

            img = nib.load(img_path).get_fdata()
            mask = nib.load(mask_path).get_fdata()

            # Normalize image to 0-255 and convert to uint8
            img = ((img - np.min(img)) / (np.max(img) - np.min(img)) * 255).astype(np.uint8)
            mask = (mask > 0).astype(np.uint8) * 255 # Binarize mask

            # Assuming axial slices are the last dimension
            for i in range(img.shape[2]):
                img_slice = Image.fromarray(img[:, :, i])
                mask_slice = Image.fromarray(mask[:, :, i])
                
                filename = f'{patient_id}_slice_{i}.png'
                has_tumor = bool(np.sum(np.array(mask_slice)) > 0)
                slice_tumor_map[filename] = has_tumor
                
                img_slice.save(os.path.join(image_dir, filename))
                mask_slice.save(os.path.join(mask_dir, filename))
                
        except IndexError:
            print(f'Skipping {patient_id} due to missing files.')
    
    # Save the map
    with open(SLICE_MAP_PATH, 'w') as f:
        json.dump(slice_tumor_map, f)
    
    pos = sum(slice_tumor_map.values())
    neg = len(slice_tumor_map) - pos
    print(f'Saved {len(slice_tumor_map)} slices: {pos} with tumor, {neg} without')
    return slice_tumor_map

# Skip extraction if data already exists
if os.path.exists(SLICE_MAP_PATH) and os.path.exists(IMAGE_DIR) and len(os.listdir(IMAGE_DIR)) > 0:
    print(f'Loading existing slice_tumor_map from {SLICE_MAP_PATH}')
    with open(SLICE_MAP_PATH, 'r') as f:
        slice_tumor_map = json.load(f)
    pos = sum(slice_tumor_map.values())
    neg = len(slice_tumor_map) - pos
    print(f'Loaded {len(slice_tumor_map)} slices: {pos} with tumor, {neg} without')
else:
    slice_tumor_map = extract_and_save_slices(patient_folders, IMAGE_DIR, MASK_DIR)
    print('Finished extracting and saving slices.')
# Out:
# Loading existing slice_tumor_map from slice_tumor_map.json
# Loaded 1806 slices: 870 with tumor, 936 without

# %%
# Define the augmentation pipeline for the training set
train_transform = A.Compose([
    A.Resize(256, 256),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.GridDistortion(p=0.5),
    A.OpticalDistortion(p=0.5, distort_limit=1, shift_limit=0.5),
    A.Affine(
        rotate=(-15, 15),
        scale=(0.9, 1.1),
        translate_percent=0.05,
        p=0.75
    ),
    A.ElasticTransform(p=0.5, alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
    A.RandomBrightnessContrast(p=0.5),
    A.Normalize(mean=(0.5,), std=(0.5,)),
    ToTensorV2(),
])

# Define a simpler pipeline for the validation set (no augmentations)
val_transform = A.Compose([
    A.Resize(256, 256),
    A.Normalize(mean=(0.5,), std=(0.5,)),
    ToTensorV2(),
])

# Load the slice tumor map
def load_slice_tumor_map():
    if os.path.exists(SLICE_MAP_PATH):
        with open(SLICE_MAP_PATH, 'r') as f:
            return json.load(f)
    return {}

slice_tumor_map = load_slice_tumor_map()

class LipomaDataset(Dataset):
    def __init__(self, image_paths, mask_paths, transform=None, slice_tumor_map=None):
        self.image_paths = image_paths
        self.mask_paths = mask_paths
        self.transform = transform
        self.slice_tumor_map = slice_tumor_map or {}
        
        # Build has_tumor flags for each sample
        self.has_tumor = []
        for img_path in self.image_paths:
            filename = os.path.basename(img_path)
            self.has_tumor.append(self.slice_tumor_map.get(filename, True))

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        mask_path = self.mask_paths[idx]
        
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        
        # Ensure mask is binary (0 or 255) before transformations
        mask = (mask > 0).astype(np.uint8) * 255

        if self.transform:
            transformed = self.transform(image=image, mask=mask)
            image = transformed['image']
            mask = transformed['mask']

        # Ensure mask tensor is binary (0 or 1) and has a channel dimension
        mask = (mask > 0.5).float().unsqueeze(0)

        return image, mask
    
    def get_balanced_sampler(self, neg_to_pos_ratio=1.0):
        """Create a WeightedRandomSampler to balance positive/negative samples.
        
        Args:
            neg_to_pos_ratio: Target ratio of negative to positive samples (1.0 = equal)
        """
        n_pos = sum(self.has_tumor)
        n_neg = len(self.has_tumor) - n_pos
        
        if n_pos == 0 or n_neg == 0:
            return None
        
        # Calculate weights: higher weight for minority class
        # For balanced sampling: weight_pos * n_pos = weight_neg * n_neg
        weight_pos = 1.0
        weight_neg = (n_pos / n_neg) * neg_to_pos_ratio
        
        weights = [weight_pos if has_tumor else weight_neg for has_tumor in self.has_tumor]
        
        return WeightedRandomSampler(
            weights=weights,
            num_samples=len(weights),
            replacement=True
        )

# Create a placeholder dataset to get all image/mask paths
all_images = sorted(glob.glob(os.path.join(IMAGE_DIR, '*.png')))
all_masks = sorted(glob.glob(os.path.join(MASK_DIR, '*.png')))

# Report balance
if slice_tumor_map:
    n_pos = sum(1 for img in all_images if slice_tumor_map.get(os.path.basename(img), True))
    n_neg = len(all_images) - n_pos
    print(f'Dataset balance: {n_pos} positive, {n_neg} negative slices')


# Demonstrate the augmentation by showing an example
if len(all_images) > 0:
    temp_dataset = LipomaDataset(image_paths=all_images, mask_paths=all_masks, 
                                  transform=train_transform, slice_tumor_map=slice_tumor_map)
    image, mask = temp_dataset[0]
    
    # Reverse normalization for visualization
    image = (image * 0.5) + 0.5
    
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    ax[0].imshow(image.squeeze(), cmap='gray')
    ax[0].set_title('Augmented Image')
    ax[1].imshow(mask.squeeze(), cmap='gray')
    ax[1].set_title('Augmented Mask')
    plt.show()
# Out:
# Dataset balance: 870 positive, 936 negative slices
# /tmp/ipykernel_45849/4056681034.py:7: UserWarning: Argument(s) 'shift_limit' are not valid for transform OpticalDistortion
#   A.OpticalDistortion(p=0.5, distort_limit=1, shift_limit=0.5),
# /tmp/ipykernel_45849/4056681034.py:14: UserWarning: Argument(s) 'alpha_affine' are not valid for transform ElasticTransform
#   A.ElasticTransform(p=0.5, alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),

# %%
IN_CHANNELS = 1
OUT_CHANNELS = 1
N_STAGES = 7
FEATURES_PER_STAGE = [32, 64, 128, 256, 320, 512, 720]
DEEP_SUPERVISION = True

def init_weights_he(module, neg_slope=1e-2):
    if isinstance(module, (nn.Conv2d, nn.ConvTranspose2d, nn.Linear)):
        nn.init.kaiming_normal_(module.weight, a=neg_slope)
        if module.bias is not None:
            nn.init.constant_(module.bias, 0)

def build_model():
    """Build nnU-Net (PlainConvUNet) for 2D segmentation with deep supervision."""
    model = PlainConvUNet(
        input_channels=IN_CHANNELS,
        n_stages=N_STAGES,
        features_per_stage=FEATURES_PER_STAGE,
        conv_op=nn.Conv2d,
        kernel_sizes=[[3, 3]] * N_STAGES,
        strides=[[1, 1]] + [[2, 2]] * (N_STAGES - 1),
        n_conv_per_stage=[2] * N_STAGES,
        n_conv_per_stage_decoder=[2] * (N_STAGES - 1),
        num_classes=OUT_CHANNELS,
        deep_supervision=DEEP_SUPERVISION,
        conv_bias=True,
        norm_op=nn.InstanceNorm2d,
        norm_op_kwargs={'eps': 1e-5, 'affine': True},
        nonlin=nn.LeakyReLU,
        nonlin_kwargs={'inplace': True},
    )
    model.apply(init_weights_he)
    return model

def get_deep_supervision_weights(n_stages):
    """nnU-Net-style deep supervision weights: 1, 1/2, 1/4, ... normalized."""
    weights = np.array([1 / (2 ** i) for i in range(n_stages - 1)])
    return weights / weights.sum()

DS_WEIGHTS = get_deep_supervision_weights(N_STAGES) if DEEP_SUPERVISION else None

model = build_model().to(device)
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'Model: nnU-Net PlainConvUNet | Stages: {N_STAGES} | Features: {FEATURES_PER_STAGE}')
print(f'Deep supervision: {DEEP_SUPERVISION} | Weights: {DS_WEIGHTS}')
print(f'Total params: {total_params:,} | Trainable: {trainable_params:,}')
# Out:
# Model: nnU-Net PlainConvUNet | Stages: 7 | Features: [32, 64, 128, 256, 320, 512, 720]
# Deep supervision: True | Weights: [0.50793651 0.25396825 0.12698413 0.06349206 0.03174603 0.01587302]
# Total params: 29,491,910 | Trainable: 29,491,910

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from scipy.ndimage import distance_transform_edt

class BoundaryLoss(nn.Module):
    """Boundary loss using distance transform."""
    def __init__(self):
        super().__init__()
    
    def compute_distance_map(self, mask):
        """Compute signed distance map: negative inside, positive outside."""
        mask_np = mask.cpu().numpy()
        batch_size = mask_np.shape[0]
        dist_maps = []
        
        for b in range(batch_size):
            m = mask_np[b, 0]
            if m.sum() == 0:  # Empty mask
                dist_maps.append(np.ones_like(m))  # All positive (penalize any prediction)
            else:
                # Negative inside (want pred=1), positive outside (want pred=0)
                pos_dist = distance_transform_edt(m)
                neg_dist = distance_transform_edt(1 - m)
                dist_map = pos_dist - neg_dist
                # Normalize to [-1, 1] range
                dist_map = np.clip(dist_map / (np.abs(dist_map).max() + 1e-8), -1, 1)
                dist_maps.append(dist_map)
        
        return torch.tensor(np.stack(dist_maps), dtype=torch.float32, device=mask.device).unsqueeze(1)
    
    def forward(self, pred, target):
        pred_sig = torch.sigmoid(pred)
        dist_map = self.compute_distance_map(target)
        # Minimize: pred * dist_map (negative where we want pred=1, positive where pred=0)
        boundary_loss = (pred_sig * dist_map).mean()
        return boundary_loss

class DiceLoss(nn.Module):
    """Standard dice loss, handles empty masks."""
    def __init__(self, smooth=1e-5):
        super().__init__()
        self.smooth = smooth
    
    def forward(self, pred, target):
        pred_sig = torch.sigmoid(pred)
        pred_flat = pred_sig.view(-1)
        target_flat = target.view(-1)
        
        intersection = (pred_flat * target_flat).sum()
        union = pred_flat.sum() + target_flat.sum()
        
        dice = (2. * intersection + self.smooth) / (union + self.smooth)
        return 1 - dice

class FocalLoss(nn.Module):
    """Focal loss for handling class imbalance."""
    def __init__(self, alpha=0.8, gamma=2.0):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
    
    def forward(self, pred, target):
        pred_flat = pred.view(-1)
        target_flat = target.view(-1)
        
        bce = F.binary_cross_entropy_with_logits(pred_flat, target_flat, reduction='none')
        pt = torch.exp(-bce)
        focal = self.alpha * (1 - pt) ** self.gamma * bce
        return focal.mean()

class CombinedLoss(nn.Module):
    """Dice + Focal + Boundary loss."""
    def __init__(self, dice_weight=0.5, focal_weight=0.3, boundary_weight=0.2):
        super().__init__()
        self.dice = DiceLoss()
        self.focal = FocalLoss()
        self.boundary = BoundaryLoss()
        self.dice_weight = dice_weight
        self.focal_weight = focal_weight
        self.boundary_weight = boundary_weight
    
    def forward(self, pred, target):
        d_loss = self.dice(pred, target)
        f_loss = self.focal(pred, target)
        b_loss = self.boundary(pred, target)
        
        total = self.dice_weight * d_loss + self.focal_weight * f_loss + self.boundary_weight * b_loss
        return total

# %%
# Hyperparameters
LEARNING_RATE = 3e-4
BATCH_SIZE = 8
NUM_EPOCHS = 50
NUM_FOLDS = 5
RUN_FOLDS = 5  # How many folds to actually run (for quick iteration)
NEG_SAMPLE_RATIO = 0.5  # Max fraction of negatives to include (reached at final epoch, linearly ramped from 0)
HOLDOUT_PATIENTS = 4
EARLY_STOP_PATIENCE = 10
WARMUP_EPOCHS = 3
NUM_PREDICTION_EXAMPLES = 10
USE_AMP = (device == 'cuda')

# %%
# Post-processing refinement: morphological ops + component filtering + hole filling
def postprocess_mask(pred_mask, min_component_size=50, morph_kernel_size=5):
    """Refine predictions with morphological closing/opening, small component removal, and hole filling."""
    from scipy import ndimage
    pred_np = pred_mask.cpu().numpy() if torch.is_tensor(pred_mask) else pred_mask
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (morph_kernel_size, morph_kernel_size))

    processed = []
    for i in range(pred_np.shape[0]):
        mask = (pred_np[i, 0] > 0.5).astype(np.uint8)
        if mask.sum() == 0:
            processed.append(mask.astype(np.float32))
            continue

        # Morphological closing (fill small gaps) then opening (remove noise)
        mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
        mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)

        labeled, num_features = ndimage.label(mask)
        if num_features == 0:
            processed.append(mask.astype(np.float32))
            continue

        # Remove components smaller than threshold
        sizes = ndimage.sum(mask, labeled, range(1, num_features + 1))
        for label_idx, size in enumerate(sizes, 1):
            if size < min_component_size:
                mask[labeled == label_idx] = 0

        # Fill holes inside remaining regions
        mask = ndimage.binary_fill_holes(mask).astype(np.float32)
        processed.append(mask)

    return torch.tensor(np.stack(processed), device=pred_mask.device).unsqueeze(1)

# Test-Time Augmentation
def _get_full_res(pred):
    """Extract full-resolution output (handles deep supervision list or plain tensor)."""
    return pred[0] if isinstance(pred, (list, tuple)) else pred

def tta_predict(model, image):
    """Apply test-time augmentation: original + flips."""
    model.eval()
    with torch.no_grad(), autocast(device_type='cuda', enabled=USE_AMP):
        logits = []
        
        logits.append(_get_full_res(model(image)))
        
        img_hflip = torch.flip(image, dims=[3])
        logits.append(torch.flip(_get_full_res(model(img_hflip)), dims=[3]))
        
        img_vflip = torch.flip(image, dims=[2])
        logits.append(torch.flip(_get_full_res(model(img_vflip)), dims=[2]))
        
        img_both = torch.flip(image, dims=[2, 3])
        logits.append(torch.flip(_get_full_res(model(img_both)), dims=[2, 3]))
        
        return torch.sigmoid(torch.stack(logits).mean(dim=0))

# Cosine annealing with warmup scheduler
class WarmupCosineScheduler:
    def __init__(self, optimizer, warmup_epochs, total_epochs, min_lr=1e-6):
        self.optimizer = optimizer
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.min_lr = min_lr
        self.base_lr = optimizer.param_groups[0]['lr']
        
    def step(self, epoch):
        if epoch < self.warmup_epochs:
            # Linear warmup
            lr = self.base_lr * (epoch + 1) / self.warmup_epochs
        else:
            # Cosine annealing
            progress = (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs)
            lr = self.min_lr + 0.5 * (self.base_lr - self.min_lr) * (1 + np.cos(np.pi * progress))
        
        for param_group in self.optimizer.param_groups:
            param_group['lr'] = lr
        return lr

# Early stopping tracker
class EarlyStopping:
    def __init__(self, patience=7, min_delta=1e-4):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.should_stop = False
        
    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss > self.best_loss - self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.should_stop = True
        else:
            self.best_loss = val_loss
            self.counter = 0
        return self.should_stop

# Dice coefficient metric (separate from loss)
def dice_metric(pred, target, threshold=0.5):
    smooth = 1.0
    pred_bin = (torch.sigmoid(pred) > threshold).float()
    
    # Per-sample dice
    intersection = (pred_bin * target).sum(dim=(2, 3))
    pred_sum = pred_bin.sum(dim=(2, 3))
    target_sum = target.sum(dim=(2, 3))
    union = pred_sum + target_sum
    
    # Handle empty masks: if both pred and target empty, dice=1
    dice = (2. * intersection + smooth) / (union + smooth)
    
    # For empty targets where pred is also empty, set dice to 1
    empty_correct = ((target_sum == 0) & (pred_sum < 10)).float()  # Allow small noise
    dice = dice * (1 - empty_correct) + empty_correct
    
    return dice.mean()

# Training and Validation Functions
def train_epoch(loader, model, optimizer, loss_fn, scaler=None, ds_weights=None):
    model.train()
    total_loss = 0
    total_dice = 0
    for images, masks in loader:
        images, masks = images.to(device), masks.to(device)
        optimizer.zero_grad(set_to_none=True)
        with autocast(device_type='cuda', enabled=USE_AMP):
            preds = model(images)
            if ds_weights is not None and isinstance(preds, (list, tuple)):
                loss = 0
                for i, (p, w) in enumerate(zip(preds, ds_weights)):
                    target = masks if i == 0 else F.interpolate(masks, size=p.shape[2:], mode='nearest')
                    loss = loss + w * loss_fn(p, target)
                full_res_pred = preds[0]
            else:
                loss = loss_fn(_get_full_res(preds), masks)
                full_res_pred = _get_full_res(preds)
        if scaler is not None:
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
        else:
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
        total_loss += loss.item()
        total_dice += dice_metric(full_res_pred.float(), masks).item()
    return total_loss / len(loader), total_dice / len(loader)

def validate_epoch(loader, model, loss_fn, use_tta=False, use_postprocess=False):
    model.eval()
    total_loss = 0
    total_dice = 0
    with torch.no_grad(), autocast(device_type='cuda', enabled=USE_AMP):
        for images, masks in loader:
            images, masks = images.to(device), masks.to(device)
            
            if use_tta:
                preds_probs = tta_predict(model, images)
                preds = torch.logit(preds_probs.clamp(1e-6, 1-1e-6))
            else:
                preds = _get_full_res(model(images))
            
            loss = loss_fn(preds.float(), masks)
            
            if use_postprocess:
                preds_processed = postprocess_mask(torch.sigmoid(preds.float()))
                pred_logits = torch.logit(preds_processed.clamp(1e-6, 1-1e-6))
                total_dice += dice_metric(pred_logits, masks).item()
            else:
                total_dice += dice_metric(preds.float(), masks).item()
            
            total_loss += loss.item()
    return total_loss / len(loader), total_dice / len(loader)

# Split patients: holdout test set + CV
patient_ids = sorted(list(set([os.path.basename(p).split('_slice_')[0] for p in all_images])))
np.random.seed(42)
np.random.shuffle(patient_ids)

# Reserve holdout patients
test_patients = patient_ids[:HOLDOUT_PATIENTS]
cv_patients = patient_ids[HOLDOUT_PATIENTS:]
print(f'Holdout test patients: {test_patients}')
print(f'CV patients: {cv_patients}')

# Create test set
test_images = [img for img in all_images if os.path.basename(img).split('_slice_')[0] in test_patients]
test_masks = [mask for mask in all_masks if os.path.basename(mask).split('_slice_')[0] in test_patients]
test_dataset = LipomaDataset(image_paths=test_images, mask_paths=test_masks, 
                              transform=val_transform, slice_tumor_map=slice_tumor_map)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_pos = sum(1 for img in test_images if slice_tumor_map.get(os.path.basename(img), False))
test_neg = len(test_images) - test_pos
print(f'Test set: {len(test_dataset)} slices from {len(test_patients)} patients ({test_pos} pos, {test_neg} neg)')

# Verify no overlap
assert len(set(test_patients) & set(cv_patients)) == 0, "Overlap between test and CV patients!"

# 5-Fold Cross-Validation on remaining patients
kf = KFold(n_splits=NUM_FOLDS, shuffle=True, random_state=42)
fold_results = []

# Higher dice weight to force model to predict positive regions
criterion = CombinedLoss(dice_weight=0.8, focal_weight=0.15, boundary_weight=0.05)

for fold, (train_patient_indices, val_patient_indices) in enumerate(kf.split(cv_patients)):
    if fold >= RUN_FOLDS:
        print(f'\nSkipping remaining folds (RUN_FOLDS={RUN_FOLDS})')
        break
    print(f'\n--- Fold {fold+1}/{RUN_FOLDS} ---')
    
    train_patients = [cv_patients[i] for i in train_patient_indices]
    val_patients = [cv_patients[i] for i in val_patient_indices]
    
    # Verify no overlap between train/val/test
    assert len(set(train_patients) & set(val_patients)) == 0, "Train/val patient overlap!"
    assert len(set(train_patients) & set(test_patients)) == 0, "Train/test patient overlap!"
    assert len(set(val_patients) & set(test_patients)) == 0, "Val/test patient overlap!"

    train_images = [img for img in all_images if os.path.basename(img).split('_slice_')[0] in train_patients]
    train_masks = [mask for mask in all_masks if os.path.basename(mask).split('_slice_')[0] in train_patients]
    val_images = [img for img in all_images if os.path.basename(img).split('_slice_')[0] in val_patients]
    val_masks = [mask for mask in all_masks if os.path.basename(mask).split('_slice_')[0] in val_patients]
    
    # Report val composition
    val_pos = sum(1 for img in val_images if slice_tumor_map.get(os.path.basename(img), False))
    val_neg = len(val_images) - val_pos
    print(f'  Train: {len(train_patients)} patients, Val: {len(val_patients)} patients ({val_pos} pos, {val_neg} neg slices)')

    # Split into positive (tumor) and negative (no tumor) slices
    pos_images = [img for img in train_images if slice_tumor_map.get(os.path.basename(img), False)]
    pos_masks = [mask for mask in train_masks if slice_tumor_map.get(os.path.basename(mask).replace('_mask', ''), False)]
    all_neg_images = [img for img in train_images if not slice_tumor_map.get(os.path.basename(img), False)]
    all_neg_masks = [mask for mask in train_masks if not slice_tumor_map.get(os.path.basename(mask).replace('_mask', ''), False)]
    total_neg = len(all_neg_images)
    print(f'  Pool: {len(pos_images)} pos, {total_neg} neg available')

    val_dataset = LipomaDataset(image_paths=val_images, mask_paths=val_masks, 
                                 transform=val_transform, slice_tumor_map=slice_tumor_map)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
    
    model = build_model().to(device)
    
    optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE)
    scheduler = WarmupCosineScheduler(optimizer, WARMUP_EPOCHS, NUM_EPOCHS)
    early_stopping = EarlyStopping(patience=EARLY_STOP_PATIENCE)
    scaler = GradScaler(enabled=USE_AMP)

    history = {'train_loss': [], 'val_loss': [], 'train_dice': [], 'val_dice': [], 'lr': []}
    best_val_dice = -1.0

    for epoch in range(NUM_EPOCHS):
        # Progressive negative sampling: linearly ramp from 0 to NEG_SAMPLE_RATIO of negatives
        neg_ratio = NEG_SAMPLE_RATIO * (epoch / max(NUM_EPOCHS - 1, 1))
        n_neg_sample = int(total_neg * neg_ratio)
        
        if n_neg_sample > 0:
            neg_indices = np.random.choice(total_neg, n_neg_sample, replace=False)
            epoch_neg_images = [all_neg_images[i] for i in neg_indices]
            epoch_neg_masks = [all_neg_masks[i] for i in neg_indices]
        else:
            epoch_neg_images, epoch_neg_masks = [], []
        
        epoch_images = pos_images + epoch_neg_images
        epoch_masks = pos_masks + epoch_neg_masks
        
        print(f'  Epoch {epoch+1}: {len(pos_images)} pos + {n_neg_sample} neg = {len(epoch_images)} total')

        train_dataset = LipomaDataset(image_paths=epoch_images, mask_paths=epoch_masks, 
                                       transform=train_transform, slice_tumor_map=slice_tumor_map)
        train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

        lr = scheduler.step(epoch)
        train_loss, train_dice = train_epoch(train_loader, model, optimizer, criterion, scaler, DS_WEIGHTS)
        val_loss, val_dice = validate_epoch(val_loader, model, criterion)

        print(f'Epoch {epoch+1}/{NUM_EPOCHS} | LR: {lr:.2e} | Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f} | Train Dice: {train_dice:.4f}, Val Dice: {val_dice:.4f}')
        
        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['train_dice'].append(train_dice)
        history['val_dice'].append(val_dice)
        history['lr'].append(lr)
        
        if val_dice > best_val_dice:
            best_val_dice = val_dice
            torch.save(model.state_dict(), f'best_nnu-net_model_fold_{fold+1}.pth')
        
        if early_stopping(val_loss):
            print(f'  Early stopping at epoch {epoch+1}')
            break

    fold_results.append({
        'history': history, 
        'model_path': f'best_nnu-net_model_fold_{fold+1}.pth', 
        'val_patients': val_patients,
        'best_val_dice': best_val_dice
    })

print('\nFinished Cross-Validation.')

# Final evaluation on holdout test set with TTA and post-processing
print('\n=== Final Test Set Evaluation ===')
for fold_idx, result in enumerate(fold_results):
    model = build_model().to(device)
    model.load_state_dict(torch.load(result['model_path']))
    
    # Without TTA/postprocess
    test_loss, test_dice = validate_epoch(test_loader, model, criterion, use_tta=False, use_postprocess=False)
    # With TTA + postprocess
    test_loss_tta, test_dice_tta = validate_epoch(test_loader, model, criterion, use_tta=True, use_postprocess=True)
    
    print(f'Fold {fold_idx+1}: Test Dice = {test_dice:.4f} | With TTA+PP = {test_dice_tta:.4f}')
# Out:
# Holdout test patients: ['IOG53', 'IOG4', 'IOG40', 'IOG7']
# CV patients: ['IOG49', 'IOG55', 'IOG14', 'IOG21', 'IOG18', 'IOG12', 'IOG16', 'IOG39', 'IOG46', 'IOG31', 'IOG28', 'IOG22', 'IOG6', 'IOG26', 'IOG19', 'IOG27', 'IOG50', 'IOG45', 'IOG41', 'IOG1', 'IOG44', 'IOG43', 'IOG15', 'IOG20', 'IOG47', 'IOG10', 'IOG54', 'IOG35', 'IOG11', 'IOG48', 'IOG38', 'IOG5', 'IOG2', 'IOG36', 'IOG29', 'IOG9', 'IOG33', 'IOG17', 'IOG56', 'IOG24', 'IOG42', 'IOG51']
# Test set: 113 slices from 4 patients (44 pos, 69 neg)
#
# --- Fold 1/5 ---
#   Train: 33 patients, Val: 9 patients (145 pos, 206 neg slices)
#   Pool: 681 pos, 661 neg available
#   Epoch 1: 681 pos + 0 neg = 681 total
# Epoch 1/50 | LR: 1.00e-04 | Train Loss: 0.7446, Val Loss: 0.7980 | Train Dice: 0.1789, Val Dice: 0.0860
#   Epoch 2: 681 pos + 6 neg = 687 total
# Epoch 2/50 | LR: 2.00e-04 | Train Loss: 0.6852, Val Loss: 0.7797 | Train Dice: 0.3049, Val Dice: 0.1065
#   Epoch 3: 681 pos + 13 neg = 694 total
# Epoch 3/50 | LR: 3.00e-04 | Train Loss: 0.6046, Val Loss: 0.7538 | Train Dice: 0.3871, Val Dice: 0.1279
#   Epoch 4: 681 pos + 20 neg = 701 total
# Epoch 4/50 | LR: 3.00e-04 | Train Loss: 0.5015, Val Loss: 0.7363 | Train Dice: 0.4808, Val Dice: 0.1374
#   Epoch 5: 681 pos + 26 neg = 707 total
# Epoch 5/50 | LR: 3.00e-04 | Train Loss: 0.4161, Val Loss: 0.7352 | Train Dice: 0.5160, Val Dice: 0.1179
#   Epoch 6: 681 pos + 33 neg = 714 total
# Epoch 6/50 | LR: 2.99e-04 | Train Loss: 0.3678, Val Loss: 0.7019 | Train Dice: 0.5317, Val Dice: 0.1646
#   Epoch 7: 681 pos + 40 neg = 721 total
# Epoch 7/50 | LR: 2.97e-04 | Train Loss: 0.3237, Val Loss: 0.7128 | Train Dice: 0.5664, Val Dice: 0.2231
#   Epoch 8: 681 pos + 47 neg = 728 total
# Epoch 8/50 | LR: 2.95e-04 | Train Loss: 0.2845, Val Loss: 0.6591 | Train Dice: 0.5932, Val Dice: 0.3372
#   Epoch 9: 681 pos + 53 neg = 734 total
# Epoch 9/50 | LR: 2.92e-04 | Train Loss: 0.2682, Val Loss: 0.6904 | Train Dice: 0.6083, Val Dice: 0.4022
#   Epoch 10: 681 pos + 60 neg = 741 total
# Epoch 10/50 | LR: 2.88e-04 | Train Loss: 0.2711, Val Loss: 0.6783 | Train Dice: 0.5936, Val Dice: 0.4724
#   Epoch 11: 681 pos + 67 neg = 748 total
# Epoch 11/50 | LR: 2.84e-04 | Train Loss: 0.2417, Val Loss: 0.6848 | Train Dice: 0.6010, Val Dice: 0.3235
#   Epoch 12: 681 pos + 74 neg = 755 total
# Epoch 12/50 | LR: 2.79e-04 | Train Loss: 0.2426, Val Loss: 0.6720 | Train Dice: 0.6136, Val Dice: 0.2777
#   Epoch 13: 681 pos + 80 neg = 761 total
# Epoch 13/50 | LR: 2.74e-04 | Train Loss: 0.2029, Val Loss: 0.6639 | Train Dice: 0.6390, Val Dice: 0.3681
#   Epoch 14: 681 pos + 87 neg = 768 total
# Epoch 14/50 | LR: 2.68e-04 | Train Loss: 0.2043, Val Loss: 0.6668 | Train Dice: 0.6542, Val Dice: 0.5090
#   Epoch 15: 681 pos + 94 neg = 775 total
# Epoch 15/50 | LR: 2.61e-04 | Train Loss: 0.2045, Val Loss: 0.6681 | Train Dice: 0.6535, Val Dice: 0.4862
#   Epoch 16: 681 pos + 101 neg = 782 total
# Epoch 16/50 | LR: 2.54e-04 | Train Loss: 0.2082, Val Loss: 0.6723 | Train Dice: 0.6326, Val Dice: 0.4265
#   Epoch 17: 681 pos + 107 neg = 788 total
# Epoch 17/50 | LR: 2.47e-04 | Train Loss: 0.1840, Val Loss: 0.6654 | Train Dice: 0.6728, Val Dice: 0.2335
#   Epoch 18: 681 pos + 114 neg = 795 total
# Epoch 18/50 | LR: 2.39e-04 | Train Loss: 0.1898, Val Loss: 0.6418 | Train Dice: 0.6682, Val Dice: 0.2947
#   Epoch 19: 681 pos + 121 neg = 802 total
# Epoch 19/50 | LR: 2.31e-04 | Train Loss: 0.1755, Val Loss: 0.6985 | Train Dice: 0.6878, Val Dice: 0.4619
#   Epoch 20: 681 pos + 128 neg = 809 total
# Epoch 20/50 | LR: 2.22e-04 | Train Loss: 0.1697, Val Loss: 0.6572 | Train Dice: 0.6737, Val Dice: 0.3378
#   Epoch 21: 681 pos + 134 neg = 815 total
# Epoch 21/50 | LR: 2.13e-04 | Train Loss: 0.1677, Val Loss: 0.6546 | Train Dice: 0.7080, Val Dice: 0.3387
#   Epoch 22: 681 pos + 141 neg = 822 total
# Epoch 22/50 | LR: 2.04e-04 | Train Loss: 0.1517, Val Loss: 0.6282 | Train Dice: 0.7239, Val Dice: 0.4468
#   Epoch 23: 681 pos + 148 neg = 829 total
# Epoch 23/50 | LR: 1.95e-04 | Train Loss: 0.1452, Val Loss: 0.6329 | Train Dice: 0.7398, Val Dice: 0.3311
#   Epoch 24: 681 pos + 155 neg = 836 total
# Epoch 24/50 | LR: 1.85e-04 | Train Loss: 0.1545, Val Loss: 0.6377 | Train Dice: 0.7183, Val Dice: 0.5279
#   Epoch 25: 681 pos + 161 neg = 842 total
# Epoch 25/50 | LR: 1.75e-04 | Train Loss: 0.1479, Val Loss: 0.6329 | Train Dice: 0.7142, Val Dice: 0.5206
#   Epoch 26: 681 pos + 168 neg = 849 total
# Epoch 26/50 | LR: 1.65e-04 | Train Loss: 0.1334, Val Loss: 0.6574 | Train Dice: 0.7589, Val Dice: 0.5026
#   Epoch 27: 681 pos + 175 neg = 856 total
# Epoch 27/50 | LR: 1.55e-04 | Train Loss: 0.1332, Val Loss: 0.6470 | Train Dice: 0.7580, Val Dice: 0.5325
#   Epoch 28: 681 pos + 182 neg = 863 total
# Epoch 28/50 | LR: 1.46e-04 | Train Loss: 0.1327, Val Loss: 0.6204 | Train Dice: 0.7482, Val Dice: 0.5168
#   Epoch 29: 681 pos + 188 neg = 869 total
# Epoch 29/50 | LR: 1.36e-04 | Train Loss: 0.1258, Val Loss: 0.5969 | Train Dice: 0.7496, Val Dice: 0.5043
#   Epoch 30: 681 pos + 195 neg = 876 total
# Epoch 30/50 | LR: 1.26e-04 | Train Loss: 0.1192, Val Loss: 0.6070 | Train Dice: 0.7812, Val Dice: 0.5747
#   Epoch 31: 681 pos + 202 neg = 883 total
# Epoch 31/50 | LR: 1.16e-04 | Train Loss: 0.1225, Val Loss: 0.5990 | Train Dice: 0.7715, Val Dice: 0.5174
#   Epoch 32: 681 pos + 209 neg = 890 total
# Epoch 32/50 | LR: 1.06e-04 | Train Loss: 0.1162, Val Loss: 0.6000 | Train Dice: 0.7740, Val Dice: 0.4685
#   Epoch 33: 681 pos + 215 neg = 896 total
# Epoch 33/50 | LR: 9.68e-05 | Train Loss: 0.1136, Val Loss: 0.5966 | Train Dice: 0.7813, Val Dice: 0.5763
#   Epoch 34: 681 pos + 222 neg = 903 total
# Epoch 34/50 | LR: 8.76e-05 | Train Loss: 0.1145, Val Loss: 0.5951 | Train Dice: 0.7896, Val Dice: 0.5297
#   Epoch 35: 681 pos + 229 neg = 910 total
# Epoch 35/50 | LR: 7.87e-05 | Train Loss: 0.1174, Val Loss: 0.6042 | Train Dice: 0.7898, Val Dice: 0.5873
#   Epoch 36: 681 pos + 236 neg = 917 total
# Epoch 36/50 | LR: 7.01e-05 | Train Loss: 0.1114, Val Loss: 0.6059 | Train Dice: 0.7914, Val Dice: 0.5605
#   Epoch 37: 681 pos + 242 neg = 923 total
# Epoch 37/50 | LR: 6.18e-05 | Train Loss: 0.1050, Val Loss: 0.5921 | Train Dice: 0.8012, Val Dice: 0.5213
#   Epoch 38: 681 pos + 249 neg = 930 total
# Epoch 38/50 | LR: 5.40e-05 | Train Loss: 0.1076, Val Loss: 0.6083 | Train Dice: 0.7918, Val Dice: 0.6065
#   Epoch 39: 681 pos + 256 neg = 937 total
# Epoch 39/50 | LR: 4.66e-05 | Train Loss: 0.0990, Val Loss: 0.6194 | Train Dice: 0.8068, Val Dice: 0.6631
#   Epoch 40: 681 pos + 263 neg = 944 total
# Epoch 40/50 | LR: 3.96e-05 | Train Loss: 0.0929, Val Loss: 0.6201 | Train Dice: 0.8270, Val Dice: 0.6490
#   Epoch 41: 681 pos + 269 neg = 950 total
# Epoch 41/50 | LR: 3.32e-05 | Train Loss: 0.0948, Val Loss: 0.5980 | Train Dice: 0.8163, Val Dice: 0.6241
#   Epoch 42: 681 pos + 276 neg = 957 total
# Epoch 42/50 | LR: 2.72e-05 | Train Loss: 0.0964, Val Loss: 0.6083 | Train Dice: 0.8330, Val Dice: 0.6223
#   Epoch 43: 681 pos + 283 neg = 964 total
# Epoch 43/50 | LR: 2.19e-05 | Train Loss: 0.0971, Val Loss: 0.6090 | Train Dice: 0.8357, Val Dice: 0.6285
#   Epoch 44: 681 pos + 290 neg = 971 total
# Epoch 44/50 | LR: 1.71e-05 | Train Loss: 0.0980, Val Loss: 0.6123 | Train Dice: 0.8231, Val Dice: 0.6321
#   Epoch 45: 681 pos + 296 neg = 977 total
# Epoch 45/50 | LR: 1.29e-05 | Train Loss: 0.1019, Val Loss: 0.6139 | Train Dice: 0.8250, Val Dice: 0.6506
#   Epoch 46: 681 pos + 303 neg = 984 total
# Epoch 46/50 | LR: 9.27e-06 | Train Loss: 0.1038, Val Loss: 0.6100 | Train Dice: 0.8323, Val Dice: 0.6086
#   Epoch 47: 681 pos + 310 neg = 991 total
# Epoch 47/50 | LR: 6.31e-06 | Train Loss: 0.0982, Val Loss: 0.6129 | Train Dice: 0.8136, Val Dice: 0.6445
#   Early stopping at epoch 47
#
# --- Fold 2/5 ---
#   Train: 33 patients, Val: 9 patients (172 pos, 188 neg slices)
#   Pool: 654 pos, 679 neg available
#   Epoch 1: 654 pos + 0 neg = 654 total
# Epoch 1/50 | LR: 1.00e-04 | Train Loss: 0.7621, Val Loss: 0.8014 | Train Dice: 0.1503, Val Dice: 0.0571
#   Epoch 2: 654 pos + 6 neg = 660 total
# Epoch 2/50 | LR: 2.00e-04 | Train Loss: 0.7130, Val Loss: 0.7806 | Train Dice: 0.2598, Val Dice: 0.0888
#   Epoch 3: 654 pos + 13 neg = 667 total
# Epoch 3/50 | LR: 3.00e-04 | Train Loss: 0.6496, Val Loss: 0.7621 | Train Dice: 0.3493, Val Dice: 0.1214
#   Epoch 4: 654 pos + 20 neg = 674 total
# Epoch 4/50 | LR: 3.00e-04 | Train Loss: 0.5609, Val Loss: 0.7513 | Train Dice: 0.4272, Val Dice: 0.1243
#   Epoch 5: 654 pos + 27 neg = 681 total
# Epoch 5/50 | LR: 3.00e-04 | Train Loss: 0.4784, Val Loss: 0.7024 | Train Dice: 0.4666, Val Dice: 0.3426
#   Epoch 6: 654 pos + 34 neg = 688 total
# Epoch 6/50 | LR: 2.99e-04 | Train Loss: 0.4137, Val Loss: 0.6999 | Train Dice: 0.4828, Val Dice: 0.3935
#   Epoch 7: 654 pos + 41 neg = 695 total
# Epoch 7/50 | LR: 2.97e-04 | Train Loss: 0.3575, Val Loss: 0.6716 | Train Dice: 0.5180, Val Dice: 0.2660
#   Epoch 8: 654 pos + 48 neg = 702 total
# Epoch 8/50 | LR: 2.95e-04 | Train Loss: 0.3177, Val Loss: 0.6655 | Train Dice: 0.5352, Val Dice: 0.2722
#   Epoch 9: 654 pos + 55 neg = 709 total
# Epoch 9/50 | LR: 2.92e-04 | Train Loss: 0.3139, Val Loss: 0.6496 | Train Dice: 0.5370, Val Dice: 0.2691
#   Epoch 10: 654 pos + 62 neg = 716 total
# Epoch 10/50 | LR: 2.88e-04 | Train Loss: 0.2892, Val Loss: 0.6477 | Train Dice: 0.5386, Val Dice: 0.3441
#   Epoch 11: 654 pos + 69 neg = 723 total
# Epoch 11/50 | LR: 2.84e-04 | Train Loss: 0.2587, Val Loss: 0.6076 | Train Dice: 0.5830, Val Dice: 0.3312
#   Epoch 12: 654 pos + 76 neg = 730 total
# Epoch 12/50 | LR: 2.79e-04 | Train Loss: 0.2496, Val Loss: 0.6079 | Train Dice: 0.6054, Val Dice: 0.3927
#   Epoch 13: 654 pos + 83 neg = 737 total
# Epoch 13/50 | LR: 2.74e-04 | Train Loss: 0.2330, Val Loss: 0.6205 | Train Dice: 0.6092, Val Dice: 0.3178
#   Epoch 14: 654 pos + 90 neg = 744 total
# Epoch 14/50 | LR: 2.68e-04 | Train Loss: 0.2464, Val Loss: 0.6309 | Train Dice: 0.5875, Val Dice: 0.4321
#   Epoch 15: 654 pos + 97 neg = 751 total
# Epoch 15/50 | LR: 2.61e-04 | Train Loss: 0.2288, Val Loss: 0.6403 | Train Dice: 0.5974, Val Dice: 0.4915
#   Epoch 16: 654 pos + 103 neg = 757 total
# Epoch 16/50 | LR: 2.54e-04 | Train Loss: 0.2407, Val Loss: 0.6238 | Train Dice: 0.5855, Val Dice: 0.4625
#   Epoch 17: 654 pos + 110 neg = 764 total
# Epoch 17/50 | LR: 2.47e-04 | Train Loss: 0.2096, Val Loss: 0.6696 | Train Dice: 0.6099, Val Dice: 0.5771
#   Epoch 18: 654 pos + 117 neg = 771 total
# Epoch 18/50 | LR: 2.39e-04 | Train Loss: 0.2150, Val Loss: 0.5767 | Train Dice: 0.6298, Val Dice: 0.5179
#   Epoch 19: 654 pos + 124 neg = 778 total
# Epoch 19/50 | LR: 2.31e-04 | Train Loss: 0.1913, Val Loss: 0.6037 | Train Dice: 0.6499, Val Dice: 0.5820
#   Epoch 20: 654 pos + 131 neg = 785 total
# Epoch 20/50 | LR: 2.22e-04 | Train Loss: 0.1838, Val Loss: 0.6375 | Train Dice: 0.6831, Val Dice: 0.5285
#   Epoch 21: 654 pos + 138 neg = 792 total
# Epoch 21/50 | LR: 2.13e-04 | Train Loss: 0.1980, Val Loss: 0.5747 | Train Dice: 0.6425, Val Dice: 0.5044
#   Epoch 22: 654 pos + 145 neg = 799 total
# Epoch 22/50 | LR: 2.04e-04 | Train Loss: 0.1798, Val Loss: 0.6091 | Train Dice: 0.6711, Val Dice: 0.6337
#   Epoch 23: 654 pos + 152 neg = 806 total
# Epoch 23/50 | LR: 1.95e-04 | Train Loss: 0.1830, Val Loss: 0.5778 | Train Dice: 0.6647, Val Dice: 0.5997
#   Epoch 24: 654 pos + 159 neg = 813 total
# Epoch 24/50 | LR: 1.85e-04 | Train Loss: 0.1857, Val Loss: 0.6348 | Train Dice: 0.6742, Val Dice: 0.6474
#   Epoch 25: 654 pos + 166 neg = 820 total
# Epoch 25/50 | LR: 1.75e-04 | Train Loss: 0.1662, Val Loss: 0.5666 | Train Dice: 0.6890, Val Dice: 0.6240
#   Epoch 26: 654 pos + 173 neg = 827 total
# Epoch 26/50 | LR: 1.65e-04 | Train Loss: 0.1610, Val Loss: 0.5707 | Train Dice: 0.6900, Val Dice: 0.4685
#   Epoch 27: 654 pos + 180 neg = 834 total
# Epoch 27/50 | LR: 1.55e-04 | Train Loss: 0.1536, Val Loss: 0.5916 | Train Dice: 0.7055, Val Dice: 0.6455
#   Epoch 28: 654 pos + 187 neg = 841 total
# Epoch 28/50 | LR: 1.46e-04 | Train Loss: 0.1668, Val Loss: 0.5701 | Train Dice: 0.7126, Val Dice: 0.4307
#   Epoch 29: 654 pos + 194 neg = 848 total
# Epoch 29/50 | LR: 1.36e-04 | Train Loss: 0.1535, Val Loss: 0.5765 | Train Dice: 0.7234, Val Dice: 0.6505
#   Epoch 30: 654 pos + 200 neg = 854 total
# Epoch 30/50 | LR: 1.26e-04 | Train Loss: 0.1358, Val Loss: 0.5625 | Train Dice: 0.7235, Val Dice: 0.6401
#   Epoch 31: 654 pos + 207 neg = 861 total
# Epoch 31/50 | LR: 1.16e-04 | Train Loss: 0.1570, Val Loss: 0.5959 | Train Dice: 0.7260, Val Dice: 0.6410
#   Epoch 32: 654 pos + 214 neg = 868 total
# Epoch 32/50 | LR: 1.06e-04 | Train Loss: 0.1369, Val Loss: 0.5858 | Train Dice: 0.7448, Val Dice: 0.6146
#   Epoch 33: 654 pos + 221 neg = 875 total
# Epoch 33/50 | LR: 9.68e-05 | Train Loss: 0.1296, Val Loss: 0.5757 | Train Dice: 0.7510, Val Dice: 0.5986
#   Epoch 34: 654 pos + 228 neg = 882 total
# Epoch 34/50 | LR: 8.76e-05 | Train Loss: 0.1338, Val Loss: 0.5545 | Train Dice: 0.7482, Val Dice: 0.6226
#   Epoch 35: 654 pos + 235 neg = 889 total
# Epoch 35/50 | LR: 7.87e-05 | Train Loss: 0.1371, Val Loss: 0.5914 | Train Dice: 0.7662, Val Dice: 0.6313
#   Epoch 36: 654 pos + 242 neg = 896 total
# Epoch 36/50 | LR: 7.01e-05 | Train Loss: 0.1276, Val Loss: 0.5683 | Train Dice: 0.7647, Val Dice: 0.6437
#   Epoch 37: 654 pos + 249 neg = 903 total
# Epoch 37/50 | LR: 6.18e-05 | Train Loss: 0.1150, Val Loss: 0.5535 | Train Dice: 0.7761, Val Dice: 0.6699
#   Epoch 38: 654 pos + 256 neg = 910 total
# Epoch 38/50 | LR: 5.40e-05 | Train Loss: 0.1176, Val Loss: 0.5852 | Train Dice: 0.7759, Val Dice: 0.6453
#   Epoch 39: 654 pos + 263 neg = 917 total
# Epoch 39/50 | LR: 4.66e-05 | Train Loss: 0.1248, Val Loss: 0.5602 | Train Dice: 0.7799, Val Dice: 0.6867
#   Epoch 40: 654 pos + 270 neg = 924 total
# Epoch 40/50 | LR: 3.96e-05 | Train Loss: 0.1203, Val Loss: 0.5447 | Train Dice: 0.7894, Val Dice: 0.6760
#   Epoch 41: 654 pos + 277 neg = 931 total
# Epoch 41/50 | LR: 3.32e-05 | Train Loss: 0.1144, Val Loss: 0.5572 | Train Dice: 0.8022, Val Dice: 0.6808
#   Epoch 42: 654 pos + 284 neg = 938 total
# Epoch 42/50 | LR: 2.72e-05 | Train Loss: 0.1262, Val Loss: 0.5562 | Train Dice: 0.7878, Val Dice: 0.6899
#   Epoch 43: 654 pos + 291 neg = 945 total
# Epoch 43/50 | LR: 2.19e-05 | Train Loss: 0.1196, Val Loss: 0.5573 | Train Dice: 0.7957, Val Dice: 0.6935
#   Epoch 44: 654 pos + 297 neg = 951 total
# Epoch 44/50 | LR: 1.71e-05 | Train Loss: 0.1049, Val Loss: 0.5524 | Train Dice: 0.8077, Val Dice: 0.6570
#   Epoch 45: 654 pos + 304 neg = 958 total
# Epoch 45/50 | LR: 1.29e-05 | Train Loss: 0.1092, Val Loss: 0.5532 | Train Dice: 0.8058, Val Dice: 0.6680
#   Epoch 46: 654 pos + 311 neg = 965 total
# Epoch 46/50 | LR: 9.27e-06 | Train Loss: 0.1164, Val Loss: 0.5567 | Train Dice: 0.8026, Val Dice: 0.6724
#   Epoch 47: 654 pos + 318 neg = 972 total
# Epoch 47/50 | LR: 6.31e-06 | Train Loss: 0.1078, Val Loss: 0.5534 | Train Dice: 0.8188, Val Dice: 0.6695
#   Epoch 48: 654 pos + 325 neg = 979 total
# Epoch 48/50 | LR: 4.00e-06 | Train Loss: 0.1108, Val Loss: 0.5566 | Train Dice: 0.8099, Val Dice: 0.6860
#   Epoch 49: 654 pos + 332 neg = 986 total
# Epoch 49/50 | LR: 2.33e-06 | Train Loss: 0.1246, Val Loss: 0.5567 | Train Dice: 0.8108, Val Dice: 0.6809
#   Epoch 50: 654 pos + 339 neg = 993 total
# Epoch 50/50 | LR: 1.33e-06 | Train Loss: 0.1063, Val Loss: 0.5582 | Train Dice: 0.8156, Val Dice: 0.6789
#   Early stopping at epoch 50
#
# --- Fold 3/5 ---
#   Train: 34 patients, Val: 8 patients (226 pos, 139 neg slices)
#   Pool: 600 pos, 728 neg available
#   Epoch 1: 600 pos + 0 neg = 600 total
# Epoch 1/50 | LR: 1.00e-04 | Train Loss: 0.7585, Val Loss: 0.7618 | Train Dice: 0.1428, Val Dice: 0.1710
#   Epoch 2: 600 pos + 7 neg = 607 total
# Epoch 2/50 | LR: 2.00e-04 | Train Loss: 0.7149, Val Loss: 0.7340 | Train Dice: 0.2376, Val Dice: 0.2491
#   Epoch 3: 600 pos + 14 neg = 614 total
# Epoch 3/50 | LR: 3.00e-04 | Train Loss: 0.6531, Val Loss: 0.6890 | Train Dice: 0.3187, Val Dice: 0.2978
#   Epoch 4: 600 pos + 22 neg = 622 total
# Epoch 4/50 | LR: 3.00e-04 | Train Loss: 0.6024, Val Loss: 0.6440 | Train Dice: 0.3463, Val Dice: 0.3327
#   Epoch 5: 600 pos + 29 neg = 629 total
# Epoch 5/50 | LR: 3.00e-04 | Train Loss: 0.5377, Val Loss: 0.5732 | Train Dice: 0.4033, Val Dice: 0.3734
#   Epoch 6: 600 pos + 37 neg = 637 total
# Epoch 6/50 | LR: 2.99e-04 | Train Loss: 0.4605, Val Loss: 0.5488 | Train Dice: 0.4317, Val Dice: 0.4026
#   Epoch 7: 600 pos + 44 neg = 644 total
# Epoch 7/50 | LR: 2.97e-04 | Train Loss: 0.4223, Val Loss: 0.6050 | Train Dice: 0.4413, Val Dice: 0.3144
#   Epoch 8: 600 pos + 52 neg = 652 total
# Epoch 8/50 | LR: 2.95e-04 | Train Loss: 0.3819, Val Loss: 0.6275 | Train Dice: 0.4712, Val Dice: 0.2668
#   Epoch 9: 600 pos + 59 neg = 659 total
# Epoch 9/50 | LR: 2.92e-04 | Train Loss: 0.3564, Val Loss: 0.5314 | Train Dice: 0.4787, Val Dice: 0.3753
#   Epoch 10: 600 pos + 66 neg = 666 total
# Epoch 10/50 | LR: 2.88e-04 | Train Loss: 0.3387, Val Loss: 0.5629 | Train Dice: 0.4861, Val Dice: 0.3419
#   Epoch 11: 600 pos + 74 neg = 674 total
# Epoch 11/50 | LR: 2.84e-04 | Train Loss: 0.3080, Val Loss: 0.5071 | Train Dice: 0.5266, Val Dice: 0.4649
#   Epoch 12: 600 pos + 81 neg = 681 total
# Epoch 12/50 | LR: 2.79e-04 | Train Loss: 0.2920, Val Loss: 0.5810 | Train Dice: 0.5321, Val Dice: 0.4265
#   Epoch 13: 600 pos + 89 neg = 689 total
# Epoch 13/50 | LR: 2.74e-04 | Train Loss: 0.2879, Val Loss: 0.5262 | Train Dice: 0.5185, Val Dice: 0.4020
#   Epoch 14: 600 pos + 96 neg = 696 total
# Epoch 14/50 | LR: 2.68e-04 | Train Loss: 0.2612, Val Loss: 0.6004 | Train Dice: 0.5672, Val Dice: 0.4138
#   Epoch 15: 600 pos + 104 neg = 704 total
# Epoch 15/50 | LR: 2.61e-04 | Train Loss: 0.2536, Val Loss: 0.5748 | Train Dice: 0.5845, Val Dice: 0.4743
#   Epoch 16: 600 pos + 111 neg = 711 total
# Epoch 16/50 | LR: 2.54e-04 | Train Loss: 0.2394, Val Loss: 0.4343 | Train Dice: 0.5826, Val Dice: 0.5351
#   Epoch 17: 600 pos + 118 neg = 718 total
# Epoch 17/50 | LR: 2.47e-04 | Train Loss: 0.2439, Val Loss: 0.4889 | Train Dice: 0.5844, Val Dice: 0.4976
#   Epoch 18: 600 pos + 126 neg = 726 total
# Epoch 18/50 | LR: 2.39e-04 | Train Loss: 0.2506, Val Loss: 0.4747 | Train Dice: 0.5791, Val Dice: 0.4258
#   Epoch 19: 600 pos + 133 neg = 733 total
# Epoch 19/50 | LR: 2.31e-04 | Train Loss: 0.2207, Val Loss: 0.4485 | Train Dice: 0.6238, Val Dice: 0.5812
#   Epoch 20: 600 pos + 141 neg = 741 total
# Epoch 20/50 | LR: 2.22e-04 | Train Loss: 0.2020, Val Loss: 0.4844 | Train Dice: 0.6431, Val Dice: 0.5585
#   Epoch 21: 600 pos + 148 neg = 748 total
# Epoch 21/50 | LR: 2.13e-04 | Train Loss: 0.1943, Val Loss: 0.4806 | Train Dice: 0.6399, Val Dice: 0.5055
#   Epoch 22: 600 pos + 156 neg = 756 total
# Epoch 22/50 | LR: 2.04e-04 | Train Loss: 0.2095, Val Loss: 0.4041 | Train Dice: 0.6415, Val Dice: 0.5841
#   Epoch 23: 600 pos + 163 neg = 763 total
# Epoch 23/50 | LR: 1.95e-04 | Train Loss: 0.2145, Val Loss: 0.6372 | Train Dice: 0.6388, Val Dice: 0.4485
#   Epoch 24: 600 pos + 170 neg = 770 total
# Epoch 24/50 | LR: 1.85e-04 | Train Loss: 0.1966, Val Loss: 0.5166 | Train Dice: 0.6489, Val Dice: 0.5097
#   Epoch 25: 600 pos + 178 neg = 778 total
# Epoch 25/50 | LR: 1.75e-04 | Train Loss: 0.1967, Val Loss: 0.4272 | Train Dice: 0.6636, Val Dice: 0.6233
#   Epoch 26: 600 pos + 185 neg = 785 total
# Epoch 26/50 | LR: 1.65e-04 | Train Loss: 0.2062, Val Loss: 0.4052 | Train Dice: 0.6647, Val Dice: 0.6249
#   Epoch 27: 600 pos + 193 neg = 793 total
# Epoch 27/50 | LR: 1.55e-04 | Train Loss: 0.1877, Val Loss: 0.5500 | Train Dice: 0.6823, Val Dice: 0.3884
#   Epoch 28: 600 pos + 200 neg = 800 total
# Epoch 28/50 | LR: 1.46e-04 | Train Loss: 0.1871, Val Loss: 0.6037 | Train Dice: 0.6866, Val Dice: 0.5022
#   Epoch 29: 600 pos + 208 neg = 808 total
# Epoch 29/50 | LR: 1.36e-04 | Train Loss: 0.1856, Val Loss: 0.5543 | Train Dice: 0.7008, Val Dice: 0.4949
#   Epoch 30: 600 pos + 215 neg = 815 total
# Epoch 30/50 | LR: 1.26e-04 | Train Loss: 0.1724, Val Loss: 0.4603 | Train Dice: 0.6908, Val Dice: 0.5399
#   Epoch 31: 600 pos + 222 neg = 822 total
# Epoch 31/50 | LR: 1.16e-04 | Train Loss: 0.1706, Val Loss: 0.6936 | Train Dice: 0.7067, Val Dice: 0.4282
#   Epoch 32: 600 pos + 230 neg = 830 total
# Epoch 32/50 | LR: 1.06e-04 | Train Loss: 0.1714, Val Loss: 0.4651 | Train Dice: 0.7273, Val Dice: 0.6114
#   Early stopping at epoch 32
#
# --- Fold 4/5 ---
#   Train: 34 patients, Val: 8 patients (128 pos, 190 neg slices)
#   Pool: 698 pos, 677 neg available
#   Epoch 1: 698 pos + 0 neg = 698 total
# Epoch 1/50 | LR: 1.00e-04 | Train Loss: 0.7404, Val Loss: 0.8045 | Train Dice: 0.2019, Val Dice: 0.0404
#   Epoch 2: 698 pos + 6 neg = 704 total
# Epoch 2/50 | LR: 2.00e-04 | Train Loss: 0.6704, Val Loss: 0.7884 | Train Dice: 0.3313, Val Dice: 0.0742
#   Epoch 3: 698 pos + 13 neg = 711 total
# Epoch 3/50 | LR: 3.00e-04 | Train Loss: 0.5956, Val Loss: 0.7819 | Train Dice: 0.4044, Val Dice: 0.0711
#   Epoch 4: 698 pos + 20 neg = 718 total
# Epoch 4/50 | LR: 3.00e-04 | Train Loss: 0.5274, Val Loss: 0.7485 | Train Dice: 0.4376, Val Dice: 0.1121
#   Epoch 5: 698 pos + 27 neg = 725 total
# Epoch 5/50 | LR: 3.00e-04 | Train Loss: 0.4481, Val Loss: 0.7001 | Train Dice: 0.4883, Val Dice: 0.1761
#   Epoch 6: 698 pos + 34 neg = 732 total
# Epoch 6/50 | LR: 2.99e-04 | Train Loss: 0.4121, Val Loss: 0.7277 | Train Dice: 0.4838, Val Dice: 0.1192
#   Epoch 7: 698 pos + 41 neg = 739 total
# Epoch 7/50 | LR: 2.97e-04 | Train Loss: 0.3681, Val Loss: 0.6814 | Train Dice: 0.4975, Val Dice: 0.3135
#   Epoch 8: 698 pos + 48 neg = 746 total
# Epoch 8/50 | LR: 2.95e-04 | Train Loss: 0.3387, Val Loss: 0.6688 | Train Dice: 0.5028, Val Dice: 0.3992
#   Epoch 9: 698 pos + 55 neg = 753 total
# Epoch 9/50 | LR: 2.92e-04 | Train Loss: 0.3144, Val Loss: 0.6279 | Train Dice: 0.5167, Val Dice: 0.3349
#   Epoch 10: 698 pos + 62 neg = 760 total
# Epoch 10/50 | LR: 2.88e-04 | Train Loss: 0.3055, Val Loss: 0.6463 | Train Dice: 0.5142, Val Dice: 0.3975
#   Epoch 11: 698 pos + 69 neg = 767 total
# Epoch 11/50 | LR: 2.84e-04 | Train Loss: 0.3014, Val Loss: 0.5845 | Train Dice: 0.5275, Val Dice: 0.5674
#   Epoch 12: 698 pos + 75 neg = 773 total
# Epoch 12/50 | LR: 2.79e-04 | Train Loss: 0.2705, Val Loss: 0.6507 | Train Dice: 0.5570, Val Dice: 0.5505
#   Epoch 13: 698 pos + 82 neg = 780 total
# Epoch 13/50 | LR: 2.74e-04 | Train Loss: 0.2724, Val Loss: 0.5901 | Train Dice: 0.5468, Val Dice: 0.6129
#   Epoch 14: 698 pos + 89 neg = 787 total
# Epoch 14/50 | LR: 2.68e-04 | Train Loss: 0.2452, Val Loss: 0.5629 | Train Dice: 0.5950, Val Dice: 0.6599
#   Epoch 15: 698 pos + 96 neg = 794 total
# Epoch 15/50 | LR: 2.61e-04 | Train Loss: 0.2429, Val Loss: 0.6069 | Train Dice: 0.5932, Val Dice: 0.6533
#   Epoch 16: 698 pos + 103 neg = 801 total
# Epoch 16/50 | LR: 2.54e-04 | Train Loss: 0.2270, Val Loss: 0.5577 | Train Dice: 0.6048, Val Dice: 0.5513
#   Epoch 17: 698 pos + 110 neg = 808 total
# Epoch 17/50 | LR: 2.47e-04 | Train Loss: 0.2195, Val Loss: 0.5140 | Train Dice: 0.6065, Val Dice: 0.7069
#   Epoch 18: 698 pos + 117 neg = 815 total
# Epoch 18/50 | LR: 2.39e-04 | Train Loss: 0.2244, Val Loss: 0.5683 | Train Dice: 0.6047, Val Dice: 0.6541
#   Epoch 19: 698 pos + 124 neg = 822 total
# Epoch 19/50 | LR: 2.31e-04 | Train Loss: 0.2104, Val Loss: 0.5368 | Train Dice: 0.6185, Val Dice: 0.6277
#   Epoch 20: 698 pos + 131 neg = 829 total
# Epoch 20/50 | LR: 2.22e-04 | Train Loss: 0.1890, Val Loss: 0.5637 | Train Dice: 0.6570, Val Dice: 0.6081
#   Epoch 21: 698 pos + 138 neg = 836 total
# Epoch 21/50 | LR: 2.13e-04 | Train Loss: 0.1990, Val Loss: 0.5368 | Train Dice: 0.6185, Val Dice: 0.6803
#   Epoch 22: 698 pos + 145 neg = 843 total
# Epoch 22/50 | LR: 2.04e-04 | Train Loss: 0.1802, Val Loss: 0.5642 | Train Dice: 0.6668, Val Dice: 0.7474
#   Epoch 23: 698 pos + 151 neg = 849 total
# Epoch 23/50 | LR: 1.95e-04 | Train Loss: 0.1841, Val Loss: 0.5362 | Train Dice: 0.6691, Val Dice: 0.7590
#   Epoch 24: 698 pos + 158 neg = 856 total
# Epoch 24/50 | LR: 1.85e-04 | Train Loss: 0.1749, Val Loss: 0.5474 | Train Dice: 0.6758, Val Dice: 0.7369
#   Epoch 25: 698 pos + 165 neg = 863 total
# Epoch 25/50 | LR: 1.75e-04 | Train Loss: 0.1713, Val Loss: 0.5306 | Train Dice: 0.6845, Val Dice: 0.6286
#   Epoch 26: 698 pos + 172 neg = 870 total
# Epoch 26/50 | LR: 1.65e-04 | Train Loss: 0.1714, Val Loss: 0.4929 | Train Dice: 0.6938, Val Dice: 0.7459
#   Epoch 27: 698 pos + 179 neg = 877 total
# Epoch 27/50 | LR: 1.55e-04 | Train Loss: 0.1517, Val Loss: 0.5194 | Train Dice: 0.7087, Val Dice: 0.6946
#   Epoch 28: 698 pos + 186 neg = 884 total
# Epoch 28/50 | LR: 1.46e-04 | Train Loss: 0.1576, Val Loss: 0.5262 | Train Dice: 0.7092, Val Dice: 0.7805
#   Epoch 29: 698 pos + 193 neg = 891 total
# Epoch 29/50 | LR: 1.36e-04 | Train Loss: 0.1643, Val Loss: 0.4859 | Train Dice: 0.6938, Val Dice: 0.7598
#   Epoch 30: 698 pos + 200 neg = 898 total
# Epoch 30/50 | LR: 1.26e-04 | Train Loss: 0.1592, Val Loss: 0.4818 | Train Dice: 0.7171, Val Dice: 0.7738
#   Epoch 31: 698 pos + 207 neg = 905 total
# Epoch 31/50 | LR: 1.16e-04 | Train Loss: 0.1376, Val Loss: 0.4791 | Train Dice: 0.7208, Val Dice: 0.7696
#   Epoch 32: 698 pos + 214 neg = 912 total
# Epoch 32/50 | LR: 1.06e-04 | Train Loss: 0.1479, Val Loss: 0.5021 | Train Dice: 0.7351, Val Dice: 0.8082
#   Epoch 33: 698 pos + 221 neg = 919 total
# Epoch 33/50 | LR: 9.68e-05 | Train Loss: 0.1530, Val Loss: 0.4938 | Train Dice: 0.7310, Val Dice: 0.7396
#   Epoch 34: 698 pos + 227 neg = 925 total
# Epoch 34/50 | LR: 8.76e-05 | Train Loss: 0.1317, Val Loss: 0.5068 | Train Dice: 0.7567, Val Dice: 0.8264
#   Epoch 35: 698 pos + 234 neg = 932 total
# Epoch 35/50 | LR: 7.87e-05 | Train Loss: 0.1289, Val Loss: 0.5073 | Train Dice: 0.7564, Val Dice: 0.7858
#   Epoch 36: 698 pos + 241 neg = 939 total
# Epoch 36/50 | LR: 7.01e-05 | Train Loss: 0.1309, Val Loss: 0.5068 | Train Dice: 0.7542, Val Dice: 0.7689
#   Epoch 37: 698 pos + 248 neg = 946 total
# Epoch 37/50 | LR: 6.18e-05 | Train Loss: 0.1290, Val Loss: 0.5068 | Train Dice: 0.7648, Val Dice: 0.8209
#   Epoch 38: 698 pos + 255 neg = 953 total
# Epoch 38/50 | LR: 5.40e-05 | Train Loss: 0.1257, Val Loss: 0.4965 | Train Dice: 0.7670, Val Dice: 0.8006
#   Epoch 39: 698 pos + 262 neg = 960 total
# Epoch 39/50 | LR: 4.66e-05 | Train Loss: 0.1268, Val Loss: 0.4735 | Train Dice: 0.7748, Val Dice: 0.8066
#   Epoch 40: 698 pos + 269 neg = 967 total
# Epoch 40/50 | LR: 3.96e-05 | Train Loss: 0.1240, Val Loss: 0.4967 | Train Dice: 0.7873, Val Dice: 0.8027
#   Epoch 41: 698 pos + 276 neg = 974 total
# Epoch 41/50 | LR: 3.32e-05 | Train Loss: 0.1165, Val Loss: 0.5020 | Train Dice: 0.7843, Val Dice: 0.8016
#   Epoch 42: 698 pos + 283 neg = 981 total
# Epoch 42/50 | LR: 2.72e-05 | Train Loss: 0.1175, Val Loss: 0.5048 | Train Dice: 0.7953, Val Dice: 0.8076
#   Epoch 43: 698 pos + 290 neg = 988 total
# Epoch 43/50 | LR: 2.19e-05 | Train Loss: 0.1116, Val Loss: 0.5053 | Train Dice: 0.8028, Val Dice: 0.8120
#   Epoch 44: 698 pos + 297 neg = 995 total
# Epoch 44/50 | LR: 1.71e-05 | Train Loss: 0.1249, Val Loss: 0.5034 | Train Dice: 0.8022, Val Dice: 0.8216
#   Epoch 45: 698 pos + 303 neg = 1001 total
# Epoch 45/50 | LR: 1.29e-05 | Train Loss: 0.1194, Val Loss: 0.5021 | Train Dice: 0.7961, Val Dice: 0.8301
#   Epoch 46: 698 pos + 310 neg = 1008 total
# Epoch 46/50 | LR: 9.27e-06 | Train Loss: 0.1099, Val Loss: 0.5003 | Train Dice: 0.8063, Val Dice: 0.8219
#   Epoch 47: 698 pos + 317 neg = 1015 total
# Epoch 47/50 | LR: 6.31e-06 | Train Loss: 0.1075, Val Loss: 0.4998 | Train Dice: 0.8085, Val Dice: 0.8101
#   Epoch 48: 698 pos + 324 neg = 1022 total
# Epoch 48/50 | LR: 4.00e-06 | Train Loss: 0.1107, Val Loss: 0.5017 | Train Dice: 0.8014, Val Dice: 0.8188
#   Epoch 49: 698 pos + 331 neg = 1029 total
# Epoch 49/50 | LR: 2.33e-06 | Train Loss: 0.1181, Val Loss: 0.5003 | Train Dice: 0.8090, Val Dice: 0.8119
#   Early stopping at epoch 49
#
# --- Fold 5/5 ---
#   Train: 34 patients, Val: 8 patients (155 pos, 144 neg slices)
#   Pool: 671 pos, 723 neg available
#   Epoch 1: 671 pos + 0 neg = 671 total
# Epoch 1/50 | LR: 1.00e-04 | Train Loss: 0.7556, Val Loss: 0.7579 | Train Dice: 0.1504, Val Dice: 0.1531
#   Epoch 2: 671 pos + 7 neg = 678 total
# Epoch 2/50 | LR: 2.00e-04 | Train Loss: 0.6997, Val Loss: 0.7176 | Train Dice: 0.2592, Val Dice: 0.2521
#   Epoch 3: 671 pos + 14 neg = 685 total
# Epoch 3/50 | LR: 3.00e-04 | Train Loss: 0.6402, Val Loss: 0.6885 | Train Dice: 0.3204, Val Dice: 0.2512
#   Epoch 4: 671 pos + 22 neg = 693 total
# Epoch 4/50 | LR: 3.00e-04 | Train Loss: 0.5703, Val Loss: 0.6243 | Train Dice: 0.3759, Val Dice: 0.3096
#   Epoch 5: 671 pos + 29 neg = 700 total
# Epoch 5/50 | LR: 3.00e-04 | Train Loss: 0.4800, Val Loss: 0.5991 | Train Dice: 0.4352, Val Dice: 0.2970
#   Epoch 6: 671 pos + 36 neg = 707 total
# Epoch 6/50 | LR: 2.99e-04 | Train Loss: 0.4259, Val Loss: 0.5515 | Train Dice: 0.4500, Val Dice: 0.3713
#   Epoch 7: 671 pos + 44 neg = 715 total
# Epoch 7/50 | LR: 2.97e-04 | Train Loss: 0.4079, Val Loss: 0.5170 | Train Dice: 0.4528, Val Dice: 0.3483
#   Epoch 8: 671 pos + 51 neg = 722 total
# Epoch 8/50 | LR: 2.95e-04 | Train Loss: 0.3453, Val Loss: 0.4830 | Train Dice: 0.5112, Val Dice: 0.5004
#   Epoch 9: 671 pos + 59 neg = 730 total
# Epoch 9/50 | LR: 2.92e-04 | Train Loss: 0.3221, Val Loss: 0.5778 | Train Dice: 0.4996, Val Dice: 0.4610
#   Epoch 10: 671 pos + 66 neg = 737 total
# Epoch 10/50 | LR: 2.88e-04 | Train Loss: 0.3189, Val Loss: 0.5180 | Train Dice: 0.5244, Val Dice: 0.3931
#   Epoch 11: 671 pos + 73 neg = 744 total
# Epoch 11/50 | LR: 2.84e-04 | Train Loss: 0.2736, Val Loss: 0.5069 | Train Dice: 0.5523, Val Dice: 0.5409
#   Epoch 12: 671 pos + 81 neg = 752 total
# Epoch 12/50 | LR: 2.79e-04 | Train Loss: 0.3008, Val Loss: 0.5110 | Train Dice: 0.5196, Val Dice: 0.4485
#   Epoch 13: 671 pos + 88 neg = 759 total
# Epoch 13/50 | LR: 2.74e-04 | Train Loss: 0.2832, Val Loss: 0.4951 | Train Dice: 0.5587, Val Dice: 0.3747
#   Epoch 14: 671 pos + 95 neg = 766 total
# Epoch 14/50 | LR: 2.68e-04 | Train Loss: 0.2616, Val Loss: 0.4664 | Train Dice: 0.5557, Val Dice: 0.5396
#   Epoch 15: 671 pos + 103 neg = 774 total
# Epoch 15/50 | LR: 2.61e-04 | Train Loss: 0.2486, Val Loss: 0.4608 | Train Dice: 0.5812, Val Dice: 0.4607
#   Epoch 16: 671 pos + 110 neg = 781 total
# Epoch 16/50 | LR: 2.54e-04 | Train Loss: 0.2391, Val Loss: 0.4591 | Train Dice: 0.5673, Val Dice: 0.4615
#   Epoch 17: 671 pos + 118 neg = 789 total
# Epoch 17/50 | LR: 2.47e-04 | Train Loss: 0.2282, Val Loss: 0.4865 | Train Dice: 0.6000, Val Dice: 0.4891
#   Epoch 18: 671 pos + 125 neg = 796 total
# Epoch 18/50 | LR: 2.39e-04 | Train Loss: 0.2551, Val Loss: 0.4789 | Train Dice: 0.5692, Val Dice: 0.4975
#   Epoch 19: 671 pos + 132 neg = 803 total
# Epoch 19/50 | LR: 2.31e-04 | Train Loss: 0.2304, Val Loss: 0.5095 | Train Dice: 0.6104, Val Dice: 0.5254
#   Epoch 20: 671 pos + 140 neg = 811 total
# Epoch 20/50 | LR: 2.22e-04 | Train Loss: 0.2276, Val Loss: 0.5183 | Train Dice: 0.6182, Val Dice: 0.5327
#   Epoch 21: 671 pos + 147 neg = 818 total
# Epoch 21/50 | LR: 2.13e-04 | Train Loss: 0.2009, Val Loss: 0.5041 | Train Dice: 0.6525, Val Dice: 0.5073
#   Epoch 22: 671 pos + 154 neg = 825 total
# Epoch 22/50 | LR: 2.04e-04 | Train Loss: 0.2116, Val Loss: 0.4850 | Train Dice: 0.6573, Val Dice: 0.5757
#   Epoch 23: 671 pos + 162 neg = 833 total
# Epoch 23/50 | LR: 1.95e-04 | Train Loss: 0.1924, Val Loss: 0.5476 | Train Dice: 0.6770, Val Dice: 0.4989
#   Epoch 24: 671 pos + 169 neg = 840 total
# Epoch 24/50 | LR: 1.85e-04 | Train Loss: 0.1698, Val Loss: 0.4937 | Train Dice: 0.6892, Val Dice: 0.5802
#   Epoch 25: 671 pos + 177 neg = 848 total
# Epoch 25/50 | LR: 1.75e-04 | Train Loss: 0.1881, Val Loss: 0.5013 | Train Dice: 0.6770, Val Dice: 0.5642
#   Epoch 26: 671 pos + 184 neg = 855 total
# Epoch 26/50 | LR: 1.65e-04 | Train Loss: 0.1753, Val Loss: 0.5762 | Train Dice: 0.6830, Val Dice: 0.5724
#   Early stopping at epoch 26
#
# Finished Cross-Validation.
#
# === Final Test Set Evaluation ===
# Fold 1: Test Dice = 0.7783 | With TTA+PP = 0.8066
# Fold 2: Test Dice = 0.7650 | With TTA+PP = 0.8238
# Fold 3: Test Dice = 0.5983 | With TTA+PP = 0.6810
# Fold 4: Test Dice = 0.7669 | With TTA+PP = 0.8233
# Fold 5: Test Dice = 0.5803 | With TTA+PP = 0.6305

# %%
# Plotting Training History
for i, result in enumerate(fold_results):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(result['history']['train_loss'], label='Train Loss')
    plt.plot(result['history']['val_loss'], label='Val Loss')
    plt.title(f'Fold {i+1} - Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(result['history']['train_dice'], label='Train Dice')
    plt.plot(result['history']['val_dice'], label='Val Dice')
    plt.title(f'Fold {i+1} - Dice Coefficient')
    plt.legend()
    plt.show()

# Displaying Qualitative Results from the best model of a fold
best_fold_idx = np.argmax([max(r['history']['val_dice']) for r in fold_results])
print(f"Showing results from Fold {best_fold_idx+1}, which had the best validation Dice score.")

# Load the best model from the best fold
best_model_path = fold_results[best_fold_idx]['model_path']
model = build_model().to(device)
model.load_state_dict(torch.load(best_model_path))
model.eval()

# Get the validation data from that fold
val_patients = fold_results[best_fold_idx]['val_patients']
val_images = [img for img in all_images if os.path.basename(img).split('_slice_')[0] in val_patients]
val_masks = [mask for mask in all_masks if os.path.basename(mask).split('_slice_')[0] in val_patients]
val_dataset = LipomaDataset(image_paths=val_images, mask_paths=val_masks, transform=val_transform)
val_loader = DataLoader(val_dataset, batch_size=NUM_PREDICTION_EXAMPLES, shuffle=True)


with torch.no_grad():
    images, masks = next(iter(val_loader))
    images, masks = images.to(device), masks.to(device)
    preds = torch.sigmoid(_get_full_res(model(images)))

    plt.figure(figsize=(15, 5 * NUM_PREDICTION_EXAMPLES))
    for i in range(NUM_PREDICTION_EXAMPLES):
        plt.subplot(NUM_PREDICTION_EXAMPLES, 3, i*3 + 1)
        plt.imshow(images[i].cpu().squeeze(), cmap='gray')
        plt.title(f'Image')
        plt.axis('off')

        plt.subplot(NUM_PREDICTION_EXAMPLES, 3, i*3 + 2)
        plt.imshow(masks[i].cpu().squeeze(), cmap='gray')
        plt.title(f'Ground Truth')
        plt.axis('off')

        plt.subplot(NUM_PREDICTION_EXAMPLES, 3, i*3 + 3)
        plt.imshow(preds[i].cpu().squeeze() > 0.5, cmap='gray')
        plt.title(f'Prediction')
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# Cross-Validation Results Summary
print('--- Cross-Validation Results ---')
final_val_dices = [max(r['history']['val_dice']) for r in fold_results]
final_val_losses = [min(r['history']['val_loss']) for r in fold_results]

for i in range(len(fold_results)):
    print(f'Fold {i+1}: Best Val Loss = {final_val_losses[i]:.4f}, Best Val Dice = {final_val_dices[i]:.4f}')

print(f'Average Best Val Loss: {np.mean(final_val_losses):.4f} +/- {np.std(final_val_losses):.4f}')
print(f'Average Best Val Dice: {np.mean(final_val_dices):.4f} +/- {np.std(final_val_dices):.4f}')
# Out:
# Showing results from Fold 4, which had the best validation Dice score.
# --- Cross-Validation Results ---
# Fold 1: Best Val Loss = 0.5921, Best Val Dice = 0.6631
# Fold 2: Best Val Loss = 0.5447, Best Val Dice = 0.6935
# Fold 3: Best Val Loss = 0.4041, Best Val Dice = 0.6249
# Fold 4: Best Val Loss = 0.4735, Best Val Dice = 0.8301
# Fold 5: Best Val Loss = 0.4591, Best Val Dice = 0.5802
# Average Best Val Loss: 0.4947 +/- 0.0662
# Average Best Val Dice: 0.6784 +/- 0.0848
